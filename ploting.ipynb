# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import calendar 
import seaborn as sns

# %%
months=list(range(1,13))

sold_qty=[round(np.random.uniform(100,200)) for x in range(1,13)]

# %%
fig,axis=plt.subplots()
plt.xticks(months,calendar.month_name[1:13],rotation=50)
plot=axis.bar(months,sold_qty,width=0.1)
plt.show()

# %%
years=
# Out:
# 159
# 163
# 118
# 133
# 144
# 173
# 111
# 184
# 190
# 176
# 117
# 199

# %%
# Out:
# array([  0, 100, 200, 300, 400, 500])

# %%
# Years under consideration
years = ["2010", "2011", "2012", "2013", "2014"]

# Available watt
columns = ['4.5W', '6.0W', '7.0W','8.5W','9.5W','13.5W','15W']
unitsSold = [
             [65, 141, 88, 111, 104, 71, 99],
             [85, 142, 89, 112, 103, 73, 98],
             [75, 143, 90, 113, 89, 75, 93],
             [65, 144, 91, 114, 90, 77, 92],
             [55, 145, 92, 115, 88, 79, 93],
            ]

# Define the range and scale for the y axis
values = np.arange(0, 600, 100)

# %%
colors=plt.cm.OrRd(np.linspace(0,0.9,len(years)))
index=np.arange(len(columns))+0
bar_width=0.7
y_offset=np.zeros(len(columns))
fig,ax=plt.subplots()
cell_text=[]
n_rows=len(unitsSold)

for row in range(n_rows):
    plot=plt.bar(index,unitsSold[row],bar_width,bottom=y_offset,color=colors[row])
    y_offset=y_offset+unitsSold[row]
    cell_text.append(['%1.1f' % (x) for x in y_offset])
    i=0
    for rect in plot:
        height=rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2.,y_offset[i],'%d' % y_offset[i],ha='center',va='bottom')
        i+=1
the_table=plt.table(cellText=cell_text,rowLabels=years,rowColours=colors,colLabels=columns,loc='bottom')
plt.xticks([])
# Out:
# ([], [])
